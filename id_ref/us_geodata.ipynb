# %%
import pandas as pd

# %% [markdown]
# # US States
# Postal and 2-digit FIPS codes for 50 US states, DC and territories (Samoa, Guam, Mariana Island, Puerto Rico and Virgin Islands)

# %%
state_fips = pd.read_csv('fips_states.csv')
state_fips
# Out:
#                        state state_code  fips
# 0                    Alabama         AL     1
# 1                     Alaska         AK     2
# 2                    Arizona         AZ     4
# 3                   Arkansas         AR     5
# 4                 California         CA     6
# 5                   Colorado         CO     8
# 6                Connecticut         CT     9
# 7       District of Columbia         DC    11
# 8                   Delaware         DE    10
# 9                    Florida         FL    12
# 10                   Georgia         GA    13
# 11                    Hawaii         HI    15
# 12                     Idaho         ID    16
# 13                  Illinois         IL    17
# 14                   Indiana         IN    18
# 15                      Iowa         IA    19
# 16                    Kansas         KS    20
# 17                  Kentucky         KY    21
# 18                 Louisiana         LA    22
# ...

# %% [markdown]
# # US Counties
# County 4-digit FIPS codes and names for 50 US states, DC and territories (Samoa, Guam, Mariana Island, Puerto Rico and Virgin Islands)

# %%
county_fips = pd.read_csv('fips_counties.csv')
county_fips.head()
# Out:
#    fips    county state  state_fips
# 0  1001  Autauga     AL           1
# 1  1003  Baldwin     AL           1
# 2  1005  Barbour     AL           1
# 3  1007     Bibb     AL           1
# 4  1009   Blount     AL           1

# %% [markdown]
# # US Cities
# Data from simplemaps.com for all incorporated US cities (includes DC and Puerto Rico). Includes state, county, coordinates, zip codes and some demographic info. Does not include unincorporated cities.

# %%
cities = pd.read_csv('simplemaps_uscities_basicv1.6/uscities_2019-09.csv')
cities.head()
# Out:
#            city    city_ascii state_id  state_name  county_fips county_name  \
# 0   South Creek   South Creek       WA  Washington        53053      Pierce
# 1        Roslyn        Roslyn       WA  Washington        53037    Kittitas
# 2       Sprague       Sprague       WA  Washington        53043     Lincoln
# 3    Gig Harbor    Gig Harbor       WA  Washington        53053      Pierce
# 4  Lake Cassidy  Lake Cassidy       WA  Washington        53061   Snohomish
#
#   county_fips_all county_name_all      lat       lng  population  density  \
# 0           53053          Pierce  46.9994 -122.3921      2500.0    125.0
# 1           53037        Kittitas  47.2507 -121.0989       947.0     84.0
# 2           53043         Lincoln  47.3048 -117.9713       441.0    163.0
# 3           53053          Pierce  47.3352 -122.5968      9507.0    622.0
# 4           53061       Snohomish  48.0639 -122.0920      3591.0    131.0
#
# ...
