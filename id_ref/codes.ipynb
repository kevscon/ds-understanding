# %%
import pandas as pd

# %% [markdown]
# # US States

# %%
# list of two-character state abbreviation 
# 50 states and DC

states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
# dictionary with state name to two-character state abbreviation
# 50 states, DC and territories

us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %% [markdown]
# # US Counties

# %%
# dataframe of US counties and 4-digit FIPS codes
# 50 states, DC and territories
pd.read_csv('us_county_codes.csv')
# Out:
#       FIPS         Name  State
# 0      1001     Autauga     AL
# 1      1003     Baldwin     AL
# 2      1005     Barbour     AL
# 3      1007        Bibb     AL
# 4      1009      Blount     AL
# ...     ...          ...   ...
# 3227  72151     Yabucoa     PR
# 3228  72153       Yauco     PR
# 3229  78010   St. Croix     VI
# 3230  78020    St. John     VI
# 3231  78030  St. Thomas     VI
#
# [3232 rows x 3 columns]

# %% [markdown]
# # US Cities

# %%
# dataframe of US city coords, population, etc.
# incorporated cities only
pd.read_csv('simplemaps_uscities_basicv1.6/uscities.csv')
# Out:
#                city    city_ascii state_id    state_name  county_fips  \
# 0       South Creek   South Creek       WA    Washington        53053
# 1            Roslyn        Roslyn       WA    Washington        53037
# 2           Sprague       Sprague       WA    Washington        53043
# 3        Gig Harbor    Gig Harbor       WA    Washington        53053
# 4      Lake Cassidy  Lake Cassidy       WA    Washington        53061
# ...             ...           ...      ...           ...          ...
# 28884      Montrose      Montrose       SD  South Dakota        46087
# 28885     Spearfish     Spearfish       SD  South Dakota        46081
# 28886         Emery         Emery       SD  South Dakota        46061
# 28887     Watertown     Watertown       SD  South Dakota        46029
# 28888       Buffalo       Buffalo       SD  South Dakota        46063
#
#       county_name county_fips_all county_name_all      lat       lng  \
# ...
